# %% [markdown]
# <a href="https://colab.research.google.com/github/Auber8a/Metodos-Numericos/blob/main/MetodoBiseccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# ---
# title: "Tarea 04 - Método de la Bisección"
# author: "Aubertin Ochoa"
# lang: es
# format:
#   pdf:
#     toc: true
#     toc-title: "Tabla de Contenidos"
# execute:
#   echo: true
#   error: false
#   warning: false
# jupyter: python3
# bibliography: ref.bib
# link-citations: true
# ---

# %% [markdown]
# ##  Escuela Politécnica Nacional
# ## Ingeniería de Ciencias de la Computación
# ##  Métodos Numéticos
# ### Aubertin Ochoa
# ### 30/10/2024

# %% [markdown]
# [Link GITHUB](https://github.com/Auber8a/Metodos-Numericos.git)
# ## 1.Bisección
# ### 1. Use el método de bisección para encontrar soluciones precisas dentro de $10^{-2}$ para $x^3 - 7x^2 + 14x - 6 = 0$ en cada intervalo.
#
# a. \([0, 1]\)
#
# b. \([1, 3.2]\)
#
# c. \([3.2, 4]\)

# %% [markdown]
# ![1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpeg](data:image/jpeg;base64,...)![2.2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 4. a. Dibuje las gráficas para $ y = x^2 - 1 $ y $ y = e^{1 - x^2} $.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rango de valores para x
x = np.linspace(-3, 3, 400)

# Definir las funciones
y1 = x**2 - 1
y2 = np.exp(1 - x**2)

# Graficar las funciones
plt.plot(x, y1, label=r'$y = x^2 - 1$', color='blue')
plt.plot(x, y2, label=r'$y = e^{1 - x^2}$', color='red')

# Añadir etiquetas y título
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráficas de $y = x^2 - 1$ y $y = e^{1 - x^2}$')

# Añadir leyenda y mostrar la gráfica
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# b. Use el método de bisección para encontrar una aproximación dentro de $10^{-3}$ para un valor en $[-2, 0]$ con $ x^2 - 1$ = $e^{1 - x^2} $.

# %% [markdown]
# ![2.4.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2.Ejercicios aplicados
# 1. Un abrevadero de longitud 𝐿 tiene una sección transversal en forma de semicírculo con radio 𝑟. (Consulte la
# figura adjunta.) Cuando se llena con agua hasta una distancia ℎ a partir de la parte superior, el volumen 𝑉 de
# agua

# %% [markdown]
# ![EjercicioA1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![3.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Un objeto que cae verticalmente a través del aire está sujeto a una resistencia viscosa, así como a la fuerza de gravedad. Suponga que un objeto con masa 𝑚 cae desde una altura 𝑠଴ y que la altura del objeto después de 𝑡 segundos es
# ### $s(t)$ = $s_0$ - $\frac{mg}{k} \, t$ + $\frac{m^2 g}{k^2} \left(1 - e^{-\frac{kt}{m}}\right)$
#
# ### donde $g = 9.8 \frac{m}{s^2} $, y \( k \) representa el coeficiente de la resistencia del aire $ Ns/m $. Suponga $ s_0$ = 300 m, m = 0.25 kg, y k = 0.1 $Ns/m$ . Encuentre dentro de \( 0.01 \) segundos el tiempo que tarda un cierto objeto de \( 0.25 \) kg en golpear el piso.

# %% [markdown]
# ![3.3.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3.Ejercicios teóricos
#
# ### Use el teorema 2.1 para encontrar una cota para el número de iteraciones necesarias para lograr una aproximación con precisión de $10^{-4}$ para la solución de $x^3 - x - 1 = 0$ que se encuentra dentro del intervalo $[1,2]$. Encuentre una aproximación para la raíz con este grado de precisión.

# %% [markdown]
# ![4.jpeg](data:image/jpeg;base64,...)
